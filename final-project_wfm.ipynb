# %%
import pandas as pd

# %%
climbing_spots["Great Falls"]
# Out:
# 'lat=38.998309&lon=-77.254038'

# %%
# Python program to find current 
# weather details of any city 
# using openweathermap api 

# import required modules 
import requests, json 

# store the openweathermap api key here 
api_key = "3bc18fb454352807692ee2c893b0f307"

# base_url variable to store openweathermap url 
base_url = "http://api.openweathermap.org/data/2.5/weather?lat="

#store the google api key
google_api_key = "AIzaSyA4moAvUIRdcVxJkUTvxb6SH3U8l2cWDjI"

#assign the google base url
google_base_url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"




############################  LOCATION USING GOOGLEMAPS API #############################




#have them enter where they want to go climbing
loc_query = input("Enter climbing destination : ")

#this replaces all spaces with "+" so as to have it work with the url
loc_query = loc_query.replace(" ", "+")

#this creates the request url from given variables
google_complete_url = google_base_url + "query=" + loc_query + "&key=" + google_api_key

#this assigns the google API response to google_response and stores it
google_response = requests.get(google_complete_url)

#store it as a json file
g = google_response.json()

#get out the results section of the file
results = g["results"]

#create an empty list
result_names = []

#extract all the result names from the file
for i in range(len(results)):
    result_names.append(results[i]["name"])

#print the result names in a nice way
from pprint import pprint
pprint(result_names)

#in case there are multiple results, have the user select one
if len(result_names) > 1:
    while True:
        result_names = [x.lower() for x in result_names]
        loc_response = input("Your entry was ambiguous. Please choose from the following list : ")
        if loc_response.lower() in result_names: break
            
#if there aren't multiple results, first one is assigned 
else: loc_response = result_names[0]

#iterate through the result_names list and make them all lowercase
result_names = [x.lower() for x in result_names]

#make the loc_response lowercase as well
loc_response = loc_response.lower()

#get the index of the selected location from the original list
loc_index = result_names.index(loc_response)

#now, use that index to extract the longitude and latitude of the location froj the json file
lat_coord = results[loc_index]["geometry"]["location"]["lat"]
lon_coord = results[loc_index]["geometry"]["location"]["lng"]

#turn them into strings
lat_coord = str(lat_coord)
lon_coord = str(lon_coord)




############################### OPENWEATHERMAP API PART ####################################





# Have them enter the units that they want their response in
units = str(input("Enter either Imperial, Standard, or Metric for desired units : "))
import string
units = units.lower()

#this assembles the openweathermap api call using the lat and lon from google maps API
complete_url = base_url + lat_coord +"&lon=" +  lon_coord + "&appid=" + api_key + "&units=" + units 

# get method of requests module 
# return response object 
response = requests.get(complete_url) 

# json method of response object 
# convert json format data into 
# python format data 
x = response.json() 


# Now x contains list of nested dictionaries 
# Check the value of "cod" key is equal to 
# "404", means city is found otherwise, 
# city is not found 
if x["cod"] != "404": 

    # store the value of "main" 
    # key in variable y 
    y = x["main"] 

    # store the value corresponding 
    # to the "temp" key of y 
    current_temperature = y["temp"] 

    # store the value corresponding 
    # to the "pressure" key of y 
    current_pressure = y["pressure"] 

    # store the value corresponding 
    # to the "humidity" key of y 
    current_humidiy = y["humidity"] 

    # store the value of "weather" 
    # key in variable z 
    z = x["weather"] 

    # store the value corresponding 
    # to the "description" key at 
    # the 0th index of z 
    weather_description = z[0]["description"] 
    
    # create an if statement for send or not conclusion
    no_send_vals = ["thunderstorm", "shower rain", "rain", "snow"]
    if weather_description in no_send_vals : 
        send_con  = "DO NOT SEND IT"
    else: send_con  = "SEND IT"

    # print following values 
    print(" Temperature = " +
                    str(current_temperature) +
        "\n atmospheric pressure = " +
                    str(current_pressure) +
        "\n humidity = " +
                    str(current_humidiy) +
        "\n description = " +
                    str(weather_description) + 
        "\n conclusion = " + 
                    str(send_con)) 
    

else: print(" Location Not Found ") 
    
    
    
    
    
################################## GET THE ROUTES SECTION ###################################

#store the base_url for API calls
mntn_proj_base_url = "https://www.mountainproject.com/data/get-routes-for-lat-lon?lat="

#store my personal API key
mntn_key = "200402814-bb4615a7ad48e4503cf1101e473cbccd"

#assemble the complete url
complete_mntn_url = mntn_proj_base_url + lat_coord + "&lon=" + lon_coord + "&key=" + mntn_key
print(complete_mntn_url)

#get the response from the api and store it
rt_response = requests.get(complete_mntn_url)

#store the response as a json
routes = rt_response.json()

#get the names and grades from the response
#create an empty list
route_desc = []

#extract all the result names from the file
for i in range(len(routes)):
    route_desc.append(results[i]["name"]) ##need to finish this part and get out names and grade
# Out:
# Enter climbing destination : NW Branch
# Enter either Imperial, Standard, or Metric for desired units : Imperial
#  Temperature = 52.61
#  atmospheric pressure = 1015
#  humidity = 21
#  description = scattered clouds
#  conclusion = SEND IT

# %%
# Python program to find current 
# weather details of any city 
# using openweathermap api 

# import required modules 
import requests, json 

# Enter your API key here 
api_key = "3bc18fb454352807692ee2c893b0f307"

# base_url variable to store url 
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Get the destination that they want to go to 
city_name = input("Enter climbing destination : ") 

# Have them enter the units that they want their response in
units = str(input("Enter either Imperial, Standard, or Metric for desired units : "))
import string
units = units.lower()

##match the climbing destination with the dictionary for lat and lon
climbing_spots = {"Great Falls":"lat=38.998309&lon=-77.254038",
                 "Carderock":"lat=38.971365&lon=-77.199501",
                 "NW Branch":"lat=39.030607&lon=-77.004650",
                 "Harper's Ferry": "lat=39.325541&lon=-77.723908"}


#Make it so that city name and climbing spot name will both work 
if city_name in climbing_spots: 
    destination = climbing_spots[city_name]
else: destination = city_name



# complete_url variable to store 
# complete url address 
if city_name in climbing_spots: complete_url = base_url + destination  + "&appid=" + api_key + "&units=" + units 
else: complete_url = base_url + "appid=" + api_key + "&q=" + destination + "&units=" + units 

# get method of requests module 
# return response object 
response = requests.get(complete_url) 

# json method of response object 
# convert json format data into 
# python format data 
x = response.json() 

print(json.dumps(x, indent = 4, sort_keys = True))
# Out:
# Enter climbing destination : NW Branch
# Enter either Imperial, Standard, or Metric for desired units : Imperial
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 39.03,
#         "lon": -77
#     },
#     "dt": 1586983407,
#     "id": 4373449,
#     "main": {
#         "feels_like": 43.3,
#         "humidity": 23,
#         "pressure": 1015,
#         "temp": 52.57,
#         "temp_max": 55.4,
#         "temp_min": 50
#     },
#     "name": "White Oak",
#     "sys": {
#         "country": "US",
#         "id": 3614,
#         "sunrise": 1586946623,
#         "sunset": 1586994298,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 6.93
#     }
# }

# %%
#google key: AIzaSyA4moAvUIRdcVxJkUTvxb6SH3U8l2cWDjI

# %%
import requests, json
google_api_key = "AIzaSyA4moAvUIRdcVxJkUTvxb6SH3U8l2cWDjI"
google_base_url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

loc_query = input("Enter climbing destination : ")
loc_query = loc_query.replace(" ", "+")

google_complete_url = google_base_url + "query=" + loc_query + "&key=" + google_api_key

google_response = requests.get(google_complete_url)

g = google_response.json()


results = g["results"]
#print(json.dumps(results, indent = 4, sort_keys = True))





result_names = []

for i in range(len(results)):
    result_names.append(results[i]["name"])

from pprint import pprint
pprint(result_names)

while True:
    result_names = [x.lower() for x in result_names]
    loc_response = input("Your entry was ambiguous. Please choose from the following list : ")
    if loc_response.lower() in result_names: break

result_names = [x.lower() for x in result_names]

loc_index = result_names.index(loc_response)

loc_coord = results[loc_index]["geometry"]["location"]

print(loc_coord)
# Out:
# Enter climbing destination : Washington DC art museum
# ['National Gallery of Art',
#  'The Kreeger Museum',
#  'Renwick Gallery of the Smithsonian American Art Museum',
#  'Smithsonian American Art Museum',
#  'Hirshhorn Museum',
#  'The Phillips Collection',
#  'National Museum of Women in the Arts',
#  'Arthur M. Sackler Gallery',
#  'National Portrait Gallery',
#  'Art Museum of the Americas',
#  'Smithsonian National Museum of African Art',
#  'American University Museum at the Katzen Arts Center',
#  'Donald W. Reynolds Center for American Art and Portraiture',
#  'D.C. Alley Museum',
#  'Freer Gallery of Art',
#  'National Gallery of Art - East Building',
#  'Smithsonian Arts and Industries Building',
#  'National Gallery of Art – Sculpture Garden',
#  'Freer|Sackler',
#  'Dumbarton Oaks Museum']
# Your entry was ambiguous. Please choose from the following list : the kreeger museum
# {'lat': 38.921846, 'lng': -77.088702}

# %%
import requests, json
google_api_key = "AIzaSyA4moAvUIRdcVxJkUTvxb6SH3U8l2cWDjI"
google_base_url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

loc_query = input("Enter climbing destination : ")
loc_query = loc_query.replace(" ", "+")

google_complete_url = google_base_url + "query=" + loc_query + "&key=" + google_api_key

google_response = requests.get(google_complete_url)

g = google_response.json()


results = g["results"]
print(json.dumps(results, indent = 4, sort_keys = True))
# Out:
# Enter climbing destination : Washington DC art museums
# [
#     {
#         "formatted_address": "Constitution Ave NW, Washington, DC 20565, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.891298,
#                 "lng": -77.019965
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.89287325,
#                     "lng": -77.0147356
#                 },
#                 "southwest": {
#                     "lat": 38.88976544999999,
#                     "lng": -77.0255952
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "05ed1348adf5bd44508f51b6cd1e666073fd36eb",
#         "name": "National Gallery of Art",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 3024,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/117615337540424601584\">Andrew Cuevas</a>"
#                 ],
#                 "photo_reference": "CmRZAAAAs_JCvB3A_eiRkR96sHD3baX087E3_oTzeZCbtYLcYbh8_zqm5XYcDBUhWSUW_oWcuuN_NJlp34e9hmOiL80BlHhunxakenp3UgRGgz_Gjy_v_rUseDe6jlMxL4F3bGSLEhCW4OgAMweN2fjjYpbKaW2-GhR54NpcsanSMS9foSZq3BAV7r1jRQ",
#                 "width": 4032
#             }
#         ],
#         "place_id": "ChIJSYxSO5u3t4kRm4eyKw_Y7Kg",
#         "plus_code": {
#             "compound_code": "VXRJ+G2 Washington, District of Columbia",
#             "global_code": "87C4VXRJ+G2"
#         },
#         "rating": 4.8,
#         "reference": "ChIJSYxSO5u3t4kRm4eyKw_Y7Kg",
#         "types": [
#             "art_gallery",
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 11847
#     },
#     {
#         "formatted_address": "2401 Foxhall Rd NW, Washington, DC 20007, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.921846,
#                 "lng": -77.088702
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.92304742989272,
#                     "lng": -77.08767172010728
#                 },
#                 "southwest": {
#                     "lat": 38.92034777010727,
#                     "lng": -77.09037137989272
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "b98ff8d26dba0a85ae0b610373d257e61b424630",
#         "name": "The Kreeger Museum",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 2491,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/111148927300193005908\">The Kreeger Museum</a>"
#                 ],
#                 "photo_reference": "CmRaAAAA_uYg7MJ8Oe_Oj_7dyYCUP78nqdv6uI-AsxzILdDi-x3E4_9vOeSTAWQhDfkrRXI6nReFNCpSCvehSXbzUkCmXZkZq-k_gSG416kekgujyHN70VqdOYQLjMqz1BuWQUblEhC-O94NozPTL5tbjV8JkJjgGhScD10n9_Pac8Ft1G_4LcPG3SfnZg",
#                 "width": 3832
#             }
#         ],
#         "place_id": "ChIJOwtLbBC2t4kRITVHc77X4mE",
#         "plus_code": {
#             "compound_code": "WWC6+PG Washington, District of Columbia",
#             "global_code": "87C4WWC6+PG"
#         },
#         "rating": 4.7,
#         "reference": "ChIJOwtLbBC2t4kRITVHc77X4mE",
#         "types": [
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 161
#     },
#     {
#         "formatted_address": "1661 Pennsylvania Ave NW, Washington, DC 20006, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.89911,
#                 "lng": -77.0390607
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.90029482989272,
#                     "lng": -77.03725789999999
#                 },
#                 "southwest": {
#                     "lat": 38.89759517010728,
#                     "lng": -77.04019389999999
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "8ad8071447edbe1999fb7669274c087282f57fdd",
#         "name": "Renwick Gallery of the Smithsonian American Art Museum",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 4032,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/118343535537766955737\">Derek Webb</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAyYrtilyVthy3dlAkEuf71l1v6dycjP0tGM_TMQM8cKHokgmY8qodjoJ56o0Mg8tOn2CMNuojB3GlwUKwvXJcpOaybZ4IxK9U4An0wrRNrhSDuRkmxB8G-C_-yyczBWCvEhDYz9CLG3NgL_PAQHRxatpvGhQXmEfUKQQ4JRF5aeYtPc8XSQ2yuQ",
#                 "width": 3024
#             }
#         ],
#         "place_id": "ChIJj2jfgLy3t4kRYSELN0_MkHk",
#         "plus_code": {
#             "compound_code": "VXX6+J9 Washington, District of Columbia",
#             "global_code": "87C4VXX6+J9"
#         },
#         "rating": 4.7,
#         "reference": "ChIJj2jfgLy3t4kRYSELN0_MkHk",
#         "types": [
#             "art_gallery",
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "store",
#             "establishment"
#         ],
#         "user_ratings_total": 3983
#     },
#     {
#         "formatted_address": "F St NW &, 8th St NW, Washington, DC 20004, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.8982044,
#                 "lng": -77.0229925
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.89967907989272,
#                     "lng": -77.02164002010728
#                 },
#                 "southwest": {
#                     "lat": 38.89697942010728,
#                     "lng": -77.02433967989272
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "6300a90c9f357c4164e3ffe4f3827cf1cacb8c04",
#         "name": "Smithsonian American Art Museum",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 3024,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/100388516380929958493\">Nicholas Bottone</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAUpVHEmfu_MOvwqEdkRwe2vh-jpH2Bbp7-RPPYDgzlrI4GI4JAzeBMEnxYTJWA3_OLnSZ6cNsIohg1t6P-My_Xczx6MIAScNWb1fsNnslOouFMd7R0SfrAHQ_KNU1cVm-EhAX8oOCjvz74aUR7RdnLM0QGhT17MFblexCx6cx_INyK7F1Nm4cvw",
#                 "width": 4032
#             }
#         ],
#         "place_id": "ChIJldJnhJG3t4kRHEGl8KSqTcY",
#         "plus_code": {
#             "compound_code": "VXXG+7R Washington, District of Columbia",
#             "global_code": "87C4VXXG+7R"
#         },
#         "price_level": 3,
#         "rating": 4.8,
#         "reference": "ChIJldJnhJG3t4kRHEGl8KSqTcY",
#         "types": [
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 2201
#     },
#     {
#         "formatted_address": "1600 21st St NW, Washington, DC 20009, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.911759,
#                 "lng": -77.0469117
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.91305712989272,
#                     "lng": -77.04550487010727
#                 },
#                 "southwest": {
#                     "lat": 38.91035747010728,
#                     "lng": -77.04820452989271
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "449d981268d83349789ba87e8be642fcd6a8151d",
#         "name": "The Phillips Collection",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 3024,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/102283062915892190702\">Matthew Ford</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAg2LsgWD0nVe76w8qTbBHynzN7-m-Gx-OYBXAriGM10JKoit3Y9fWrx4Yc71iPXFHl2YALx_GkyM8txy5O_OCxS4iaUElKqQuROvo2BI--P35Sbrq_1X7cQ7l_oGXtQ8LEhBF40bd1ULrgQP8MHu043e6GhTcb0wnyN8MCr8NIAA7m_zqq0e5SA",
#                 "width": 4032
#             }
#         ],
#         "place_id": "ChIJERCNwci3t4kR92ClBSxkv14",
#         "plus_code": {
#             "compound_code": "WX63+P6 Washington, District of Columbia",
#             "global_code": "87C4WX63+P6"
#         },
#         "rating": 4.7,
#         "reference": "ChIJERCNwci3t4kR92ClBSxkv14",
#         "types": [
#             "art_gallery",
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "store",
#             "establishment"
#         ],
#         "user_ratings_total": 1148
#     },
#     {
#         "formatted_address": "Independence Ave SW &, 7th St SW, Washington, DC 20560, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.8881608,
#                 "lng": -77.0229682
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.88950082989273,
#                     "lng": -77.02160177010727
#                 },
#                 "southwest": {
#                     "lat": 38.88680117010728,
#                     "lng": -77.02430142989272
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "bd3863b77a04c32b949e40b160c47cabbed1053c",
#         "name": "Hirshhorn Museum",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 599,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/102217168661788491145\">Hirshhorn Museum</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAUruFoJpTMfKYRiJziGBjgLjzTDEJVSqVM88_PSVQm2cVisykp0b7RSvImts0qeBO6T2IdOLfF5zUkp9WAdFgKCCsP8oEd3Ie9WGcBd0sa8n4CS6x27zr7R62g1L4kOczEhA-Kff3i_pqoi_hZrSo0E4aGhSWvEygtdq0xG6SIV9NUOQLLWfVag",
#                 "width": 898
#             }
#         ],
#         "place_id": "ChIJhx1puJy3t4kRmXVaeMNjBDU",
#         "plus_code": {
#             "compound_code": "VXQG+7R Washington, District of Columbia",
#             "global_code": "87C4VXQG+7R"
#         },
#         "rating": 4.5,
#         "reference": "ChIJhx1puJy3t4kRmXVaeMNjBDU",
#         "types": [
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 3832
#     },
#     {
#         "formatted_address": "1250 New York Ave NW, Washington, DC 20005, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.9002339,
#                 "lng": -77.0289684
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.90152872989272,
#                     "lng": -77.02795507010728
#                 },
#                 "southwest": {
#                     "lat": 38.89882907010728,
#                     "lng": -77.03065472989273
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "dcc81e71767b39568ba583b22f3389ff091b58b8",
#         "name": "National Museum of Women in the Arts",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 666,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/104699272431186907942\">National Museum of Women in the Arts</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAj3y_QV4n0rKF5UajXeX_VaplUF7Ozqg62b3dzl1V_V-b6uWdF_toT7BA96XKE-0obtKwiXarwMdAr0K7WCDQX6hbS92Q6FpROu0KCSJ6FFFvDlavGmR6WYAZDkrP7DS7EhCbdZlQJn8tgUOMfZwIKSW5GhRRfziG-ZQNlOZIE7MXBaZShBYQlg",
#                 "width": 999
#             }
#         ],
#         "place_id": "ChIJcyy3n5a3t4kRQpgS0C_S6U8",
#         "plus_code": {
#             "compound_code": "WX2C+3C Washington, District of Columbia",
#             "global_code": "87C4WX2C+3C"
#         },
#         "rating": 4.6,
#         "reference": "ChIJcyy3n5a3t4kRQpgS0C_S6U8",
#         "types": [
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 1025
#     },
#     {
#         "formatted_address": "1050 Independence Ave SW, Washington, DC 20560, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.8879521,
#                 "lng": -77.02636849999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.88958427989272,
#                     "lng": -77.02386544999997
#                 },
#                 "southwest": {
#                     "lat": 38.88688462010727,
#                     "lng": -77.02800925
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "97915292bbd14e8410ad9c57204e6e7334b24040",
#         "name": "Arthur M. Sackler Gallery",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 1280,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/104596856248078658268\">Rouslan Valonen</a>"
#                 ],
#                 "photo_reference": "CmRaAAAATNcw6CUV7sy51D7E9fD9N4AqNYbcy21AN_kGWy2t3B2JHUzqPhWJzTkZLM9g1QAfz24VlQZG5TZIQ6upz9FwhL-q3XSJKkF1lIXuu0c3NZwtHFCT7n2pCCJPTQRf_gGsEhAuhIns-H-ZsP6eYA-WdYPuGhQHPbv1tKjeix62sZDrpBD_XwIY9Q",
#                 "width": 1920
#             }
#         ],
#         "place_id": "ChIJjSN0Kpy3t4kRYfYpsKGZ8IM",
#         "plus_code": {
#             "compound_code": "VXQF+5F Washington, District of Columbia",
#             "global_code": "87C4VXQF+5F"
#         },
#         "rating": 4.7,
#         "reference": "ChIJjSN0Kpy3t4kRYfYpsKGZ8IM",
#         "types": [
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 866
#     },
#     {
#         "formatted_address": "8th St NW & F St NW, Washington, DC 20001, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.8978692,
#                 "lng": -77.0230529
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.89917782989273,
#                     "lng": -77.02168477010727
#                 },
#                 "southwest": {
#                     "lat": 38.89647817010728,
#                     "lng": -77.02438442989272
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "7bc42553a7a6a2303ed81f62891d54677f57aa76",
#         "name": "National Portrait Gallery",
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 2435,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/100298517341406682872\">Jessica Gonzalez</a>"
#                 ],
#                 "photo_reference": "CmRaAAAATdLla9HuUIKxZSfurgR1rl8h84OjBuGTm6CdXZT4aagyLvvtALMYccIkd9XEBYezlznJ5aBi65kUlVMfHJubOae8Q1tB_bdNxDw_s-kK1xUm08hR3kVNS9ZEDcdzPgKzEhDfyg6dt239hJ4f6cIXweKzGhRvgQNXqYFxMj_mM46AzOEh_Xs_4g",
#                 "width": 6568
#             }
#         ],
#         "place_id": "ChIJldJnhJG3t4kRnJ3McC1qVyo",
#         "plus_code": {
#             "compound_code": "VXXG+4Q Washington, District of Columbia",
#             "global_code": "87C4VXXG+4Q"
#         },
#         "rating": 4.8,
#         "reference": "ChIJldJnhJG3t4kRnJ3McC1qVyo",
#         "types": [
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 9041
#     },
#     {
#         "formatted_address": "201 18th St NW, Washington, DC 20006, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.8928167,
#                 "lng": -77.0415472
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.89420132989272,
#                     "lng": -77.04030172010728
#                 },
#                 "southwest": {
#                     "lat": 38.89150167010728,
#                     "lng": -77.04300137989273
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "3c47a37336f63520cfd4e58d66afea3760036de6",
#         "name": "Art Museum of the Americas",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 2268,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/115051191537851472861\">Pablo Zuniga</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAiliSHj5aTw9SxX1a2cs66ssu9wFMVL-vqw-lFZK-xurmHafZkhz_S--OFLiD0jN7zeaIlJMVhKFkdvGGVR9Gz-gh9TZwHUm6BwLDs7nQdJvUpgBEK5N_I5jhNbgb_0RKEhCuzWSDY9Rj63T6qcNnuAKyGhRhC-4ClHp9HZ12q4fqEUdjHUYGDw",
#                 "width": 4032
#             }
#         ],
#         "place_id": "ChIJVVr-LaS3t4kRXYBqw5iV7Lg",
#         "plus_code": {
#             "compound_code": "VXV5+49 Washington, District of Columbia",
#             "global_code": "87C4VXV5+49"
#         },
#         "rating": 4.5,
#         "reference": "ChIJVVr-LaS3t4kRXYBqw5iV7Lg",
#         "types": [
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 214
#     },
#     {
#         "formatted_address": "950 Independence Ave SW, Washington, DC 20560, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.887988,
#                 "lng": -77.02551299999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.88912772989272,
#                     "lng": -77.02303489999998
#                 },
#                 "southwest": {
#                     "lat": 38.88642807010728,
#                     "lng": -77.02721930000001
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "89078818d513b7008e53d486f5cd5dd63c847bfb",
#         "name": "Smithsonian National Museum of African Art",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 1316,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/115625056886314082092\">Glyn Lowe Photoworks</a>"
#                 ],
#                 "photo_reference": "CmRaAAAA96OKIwaJFri38-yOQwPKuQQvUlxncf5RxjVdssB0c2lEV9JTETlGp3-rskg3bG0wczDur-rZEv0oKwldE4eM4UAppGg1_fHwxGWasjhqeXlVgeHTsg2UrW2mk1VTJB7dEhAJ-N1fNEfz9Rgrw81h0ea7GhTSH70lguRPT7qtmgS3DYXrAJ8GuQ",
#                 "width": 2000
#             }
#         ],
#         "place_id": "ChIJE6vLRJy3t4kRjODhzzjXxZc",
#         "plus_code": {
#             "compound_code": "VXQF+5Q Washington, District of Columbia",
#             "global_code": "87C4VXQF+5Q"
#         },
#         "rating": 4.7,
#         "reference": "ChIJE6vLRJy3t4kRjODhzzjXxZc",
#         "types": [
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 266
#     },
#     {
#         "formatted_address": "4400 Massachusetts Ave NW, Washington, DC 20016, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.93871499999999,
#                 "lng": -77.086236
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.93993102989272,
#                     "lng": -77.08504812010729
#                 },
#                 "southwest": {
#                     "lat": 38.93723137010728,
#                     "lng": -77.08774777989274
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "d91c26a05b0d73b887819a921d6fd57736b4efe5",
#         "name": "American University Museum at the Katzen Arts Center",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 2988,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/105910946389968171757\">Koushik C</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAN3aKLpYmCzqoWN2OBnktTi498CH_HSfCoM7OpRrgm2keAhyZCbpz1reYhYM0m-DQzBK5LjathJKvidrE6fwSITGIYEwPTrdM3rKr9PXdcf4M5a0qa4q4ZtluZx2l40DsEhAiNoTPUzjSJsG5b1Oc02-MGhTGNW_qGpjE0a6Gy2dGJmxQMgn2sg",
#                 "width": 5312
#             }
#         ],
#         "place_id": "ChIJs9U8YuPJt4kRdJhpW4Zx6kc",
#         "plus_code": {
#             "compound_code": "WWQ7+FG Washington, District of Columbia",
#             "global_code": "87C4WWQ7+FG"
#         },
#         "rating": 4.6,
#         "reference": "ChIJs9U8YuPJt4kRdJhpW4Zx6kc",
#         "types": [
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 33
#     },
#     {
#         "formatted_address": "1050 Independence Ave SW, Washington, DC 20560, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.8879143,
#                 "lng": -77.0273875
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.88909052989272,
#                     "lng": -77.02604102010727
#                 },
#                 "southwest": {
#                     "lat": 38.88639087010728,
#                     "lng": -77.02874067989272
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "b61e86855967f5665ae9721729f175fcc1b5e481",
#         "name": "Freer Gallery of Art",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 4032,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/112670809002789391171\">Hristina Ridgway</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAYp1PRshH0NxPHAc-wxHXcjeJF4039LIl8Rrk3ovakahjc9PzNdQggnDgzL3jizXQTHZQ7tEEjy_yTmd76XXUz0WYcb93sc_Ox6Hx_jhzTy1vhs0X9RNQYHYI_ZiM_M_DEhBPdjXGQ2q1gbA4SgYN-Ee8GhSxS_1w8-AjoE81d4U86Uo2ZGtVqg",
#                 "width": 3024
#             }
#         ],
#         "place_id": "ChIJmRVxrgS3t4kROE7FI_d8v30",
#         "plus_code": {
#             "compound_code": "VXQF+52 Washington, District of Columbia",
#             "global_code": "87C4VXQF+52"
#         },
#         "rating": 4.7,
#         "reference": "ChIJmRVxrgS3t4kROE7FI_d8v30",
#         "types": [
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 87
#     },
#     {
#         "formatted_address": "Blagden Alley NW, Washington, DC 20001, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.90641129999999,
#                 "lng": -77.0250764
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.90777612989272,
#                     "lng": -77.02372642010727
#                 },
#                 "southwest": {
#                     "lat": 38.90507647010728,
#                     "lng": -77.02642607989272
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "7eee2df25eedf7496fed1ba90663d0944a2051ec",
#         "name": "D.C. Alley Museum",
#         "photos": [
#             {
#                 "height": 2448,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/101635290733072870081\">Johny Mccahill</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAiQy1x25CNTUeHrbhQkwV6qFN4Cn3PacyXwR-hygTB-X7G4ZB8fRHjQ_3BxrbiOJ_drKPZ4szLlrDLfjHVmNgsBJ1V9BacUPfJbGDxM0EEMUSg2gcWOZqF-exIFzEscIMEhBjzGW5U1e2x4e2iedHwLAqGhSCz9lKoIUu8uub5JEhk8XmoA5g7w",
#                 "width": 3264
#             }
#         ],
#         "place_id": "ChIJRb7S4Oy3t4kRxZ30NqxXjBI",
#         "plus_code": {
#             "compound_code": "WX4F+HX Washington, District of Columbia",
#             "global_code": "87C4WX4F+HX"
#         },
#         "rating": 4.6,
#         "reference": "ChIJRb7S4Oy3t4kRxZ30NqxXjBI",
#         "types": [
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 42
#     },
#     {
#         "formatted_address": "2455 6th St NW, Washington, DC 20059, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.9245778,
#                 "lng": -77.02092499999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.92586822989272,
#                     "lng": -77.01981837010727
#                 },
#                 "southwest": {
#                     "lat": 38.92316857010728,
#                     "lng": -77.02251802989271
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "8f44eabb20d6c862f37f31e113112412f2ce1fd5",
#         "name": "Howard University Art Gallery",
#         "photos": [
#             {
#                 "height": 960,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/104229679244641766158\">Kat Lee</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAovVEJWFHW9dhBTRljkfW960fZVEDehvtxJKaLgR8mD73YBvgAkaTexkins_5OEvJU1FshH13xOB6PDNK2_fOb92VykIRay6LtYmSl0Kudq5J4s_cbK3c3T2ZqfbaiodIEhAvr8Ub2ElNzjGxby7YgU0oGhRIPPLRR5KpAIqltxG8bDeqRg0H6Q",
#                 "width": 1280
#             }
#         ],
#         "place_id": "ChIJraVB2Py3t4kRlaHGSNPiKic",
#         "plus_code": {
#             "compound_code": "WXFH+RJ Washington, District of Columbia",
#             "global_code": "87C4WXFH+RJ"
#         },
#         "rating": 4.6,
#         "reference": "ChIJraVB2Py3t4kRlaHGSNPiKic",
#         "types": [
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 12
#     },
#     {
#         "formatted_address": "900 Jefferson Dr SW, Washington, DC 20560, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.8881804,
#                 "lng": -77.0246002
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.88951362989273,
#                     "lng": -77.02284847010728
#                 },
#                 "southwest": {
#                     "lat": 38.88681397010728,
#                     "lng": -77.02554812989271
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "e6a2e9b5b395dd346c62e2b5741d3ec2ee0b7514",
#         "name": "Smithsonian Arts and Industries Building",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 4032,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/101810068829626301924\">Austin Graff</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAYInQfixtYQn80m7tstq4X4JeHLBvhRBfpFcZKwWkD72fllRXj1Hh4GaC5t9XCeJzMR_8IrWby2avdXHEkW085xJhKiboczebASETx9k31WN3YPIFV4JUyhyqdyxu92JwEhBSe6lZjDfy6__Pffff0I4PGhSCrpVfgE4LOBExtT2KiZPWP4z2xA",
#                 "width": 3024
#             }
#         ],
#         "place_id": "ChIJHUfUkZy3t4kRBxXKTC_e7XM",
#         "plus_code": {
#             "compound_code": "VXQG+75 Washington, District of Columbia",
#             "global_code": "87C4VXQG+75"
#         },
#         "rating": 4.4,
#         "reference": "ChIJHUfUkZy3t4kRBxXKTC_e7XM",
#         "types": [
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 73
#     },
#     {
#         "formatted_address": "1703 32nd St NW, Washington, DC 20007, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.914148,
#                 "lng": -77.0640129
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.91546427989272,
#                     "lng": -77.06277977010727
#                 },
#                 "southwest": {
#                     "lat": 38.91276462010728,
#                     "lng": -77.06547942989272
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "b9c8149db1aa13d6af7bf94fbf9fcde37a4a1b1d",
#         "name": "Dumbarton Oaks Museum",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 3024,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/106771633319064169806\">Adam Eriksen</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAIwhIPYuQ3oxfUkWllZllFZNaNdGFyI5fzUzB0VGNAOvkQXOWXGoNEkghfva5Q5FqhzXdKSH3N1niLUyDWG4gdlqPYlw9MM8lTH_18NGAvifXYGRLuaBdXFOpPx8CYzvgEhA-k5is4EJt7k93Qv33uvToGhR8wVE48boCpVYBXmRrVsyaDQ_NlA",
#                 "width": 4032
#             }
#         ],
#         "place_id": "ChIJF3PcMjG2t4kR19u0kHrlJsI",
#         "plus_code": {
#             "compound_code": "WW7P+M9 Washington, District of Columbia",
#             "global_code": "87C4WW7P+M9"
#         },
#         "rating": 4.7,
#         "reference": "ChIJF3PcMjG2t4kR19u0kHrlJsI",
#         "types": [
#             "tourist_attraction",
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 360
#     },
#     {
#         "formatted_address": "701 21st St NW, Washington, DC 20052, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.8987488,
#                 "lng": -77.0464756
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.90010332989272,
#                     "lng": -77.04521957010726
#                 },
#                 "southwest": {
#                     "lat": 38.89740367010727,
#                     "lng": -77.04791922989271
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",
#         "id": "78b8665718206f6eb7ac7a513de2ae7e4ecb2280",
#         "name": "George Washington University Art",
#         "photos": [
#             {
#                 "height": 4000,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/110794544223973421505\">Greg Dumas</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAN21gS_S2qH1k0NC3poeclxxOOtMo3XkSRY_8C7jOqFVptP_77VEEO8WtwdKcqr8Sk7ckiwx32nG4-oGxgiJD0GM4zSAq0QTNGAZnTqqW6D2RmTuroajJDM5fj5vN35W1EhAU0gRox8kIchFm8r5vgnYTGhQmDecvEE57lQE9WmeCDBksIzxQsA",
#                 "width": 6000
#             }
#         ],
#         "place_id": "ChIJpXo8DrG3t4kRu8ffCSVJb6U",
#         "plus_code": {
#             "compound_code": "VXX3+FC Washington, District of Columbia",
#             "global_code": "87C4VXX3+FC"
#         },
#         "rating": 5,
#         "reference": "ChIJpXo8DrG3t4kRu8ffCSVJb6U",
#         "types": [
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 2
#     },
#     {
#         "formatted_address": "750 9th St NW, Washington, DC 20001, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.89945489999999,
#                 "lng": -77.0243328
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.90080367989272,
#                     "lng": -77.02281107010728
#                 },
#                 "southwest": {
#                     "lat": 38.89810402010728,
#                     "lng": -77.02551072989272
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/civic_building-71.png",
#         "id": "830c60339c81a87370d41b07491309a8ccaba98e",
#         "name": "Administrative Offices of the Smithsonian American Art Museum",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 4608,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/110340141477234279592\">Zaw Khun Naw Hpunggan</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAoxK_OWkThE3-OOqaJw1Qs5Dz7b4f0Eo6iT9FnLMiAeGBoQm3d4dY2mtVRAJRNme71-9fH0wtDRH4RKkAqZt52IRdZiWoRhug3pl2zgWP4O4-Skr1m8yE_Dr6NWR8MkHyEhD07d31wN_vC-y3KMQ-dov9GhRTFEgiY3F5qISLIAQGfvLvGNmFkw",
#                 "width": 2592
#             }
#         ],
#         "place_id": "ChIJldJnhJG3t4kRZVZjAop8uhs",
#         "plus_code": {
#             "compound_code": "VXXG+Q7 Washington, District of Columbia",
#             "global_code": "87C4VXXG+Q7"
#         },
#         "rating": 4.6,
#         "reference": "ChIJldJnhJG3t4kRZVZjAop8uhs",
#         "types": [
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 8
#     },
#     {
#         "formatted_address": "9 Hillyer Ct NW, Washington, DC 20008, United States",
#         "geometry": {
#             "location": {
#                 "lat": 38.912201,
#                 "lng": -77.04727299999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 38.91351332989272,
#                     "lng": -77.04593067010728
#                 },
#                 "southwest": {
#                     "lat": 38.91081367010728,
#                     "lng": -77.04863032989272
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/museum-71.png",
#         "id": "4514ddebad3cbbbebbc5f90821a843b216f438e0",
#         "name": "IA&A at Hillyer",
#         "place_id": "ChIJKQ8A0ci3t4kRdhycmXTs600",
#         "plus_code": {
#             "compound_code": "WX63+V3 Washington, District of Columbia",
#             "global_code": "87C4WX63+V3"
#         },
#         "rating": 0,
#         "reference": "ChIJKQ8A0ci3t4kRdhycmXTs600",
#         "types": [
#             "museum",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 0
#     }
# ]
